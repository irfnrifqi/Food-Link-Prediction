# %%
# import packages
import random
import warnings
warnings.filterwarnings('ignore')
import functools
import itertools
from typing import List, Sequence, Tuple

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rdflib
from sklearn.manifold import TSNE
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC

import sys
sys.path.append('pyRDF2Vec')
sys.path.append('pyRDF2Vec/pyrdf2vec')

from pyrdf2vec import RDF2VecTransformer
from pyrdf2vec.graphs import KG
from pyrdf2vec.embedders import Word2Vec
from pyrdf2vec.walkers import (
    AnonymousWalker,
    CommunityWalker,
    HalkWalker,
    NGramWalker,
    RandomWalker,
    WalkletWalker,
    WeisfeilerLehmanWalker,
)
from pyrdf2vec.samplers import (
    ObjPredFreqSampler,
    PredFreqSampler,
    UniformSampler,
    ObjFreqSampler,
    PageRankSampler,
)

import pickle

# %%
# memdefinisikan entities yang ada menggunakan csv
data = pd.read_csv('Node2Vec 100')
entities = data['uri']

label_predicates = [
     'http://www.w3.org/1999/02/22-rdf-syntax-ns/',
     'http://www.w3.org/2000/01/rdf-schema/',
     'http://www.w3.org/2002/07/owl/',
     'http://www.w3.org/2001/XMLSchema/',
     'http://xmlns.com/foaf/0.1/',
     'http://halal.addi.is.its.ac.id/halalv.ttl/',
     'http://halal.addi.is.its.ac.id/foodproducts/',
     'http://halal.addi.is.its.ac.id/ingredients/',
     'http://halal.addi.is.its.ac.id/certificates/',
     'http://halal.addi.is.its.ac.id/sources/',
     'http://halal.addi.is.its.ac.id/manufactures/'
     'http://purl.org/foodontology/',
     'http://data.lirmm.fr/ontologies/food/',
     'http://purl.org/goodrelations/v1/',
     'http://dbpedia.org/resource/',
]

# %%
entities
# Out:
# 0        http://halal.addi.is.its.ac.id/manufactures/Je...
# 1        http://halal.addi.is.its.ac.id/manufactures/Am...
# 2        http://halal.addi.is.its.ac.id/manufactures/St...
# 3        http://halal.addi.is.its.ac.id/manufactures/Li...
# 4        http://halal.addi.is.its.ac.id/manufactures/Yi...
#                                ...
# 21234    http://halal.addi.is.its.ac.id/manufactures/Pf...
# 21235    http://halal.addi.is.its.ac.id/manufactures/Te...
# 21236    http://halal.addi.is.its.ac.id/manufactures/By...
# 21237    http://halal.addi.is.its.ac.id/manufactures/My...
# 21238    http://halal.addi.is.its.ac.id/manufactures/Mr...
# Name: uri, Length: 21239, dtype: object

# %%
# mendefinisikan knowledge graph menggunakan file n-triple
from pyrdf2vec.graphs import KG
kg = KG('rdf.nt', 
        label_predicates=[rdflib.URIRef(x) for x in label_predicates])

# %%
# mencari entities yang ada di dalam knowledge graph
filtered_entities = [e for e in entities if e in kg._entities]
filtered_entities
# Out:
# ['http://halal.addi.is.its.ac.id/manufactures/Jeunesse_Llc',
#  'http://halal.addi.is.its.ac.id/manufactures/American_Halal_Co_Inc',
#  'http://halal.addi.is.its.ac.id/manufactures/Stonyfield',
#  'http://halal.addi.is.its.ac.id/manufactures/Lian_Hoe_Tea_Coffee_M_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Yi_Quan_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/Solgar_Inc',
#  'http://halal.addi.is.its.ac.id/manufactures/Hong_Kong_Roast_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/G_G_Century_M_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Uno_Nutrition_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Mai_Wai_Foods_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Gamat_Emas_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Salim_Mk_Frozen_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Sun_Maid_Growers_Of_California',
#  'http://halal.addi.is.its.ac.id/manufactures/Punjab_Milk_Foods',
#  'http://halal.addi.is.its.ac.id/manufactures/Burman_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Young_Living_Essential_Oils_Lc',
#  'http://halal.addi.is.its.ac.id/manufactures/Cofibar_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Kimi_Sweet_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/General_Mills',
#  'http://halal.addi.is.its.ac.id/manufactures/Jz_Oriental_Delight_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Prima_Fine_Foods_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Carey_Food_Services_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Third_Street_Inc',
#  'http://halal.addi.is.its.ac.id/manufactures/Tin_Hong_Loke_Guan_Bakery_Confectionery_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Hua_Chi_Health_Resources',
#  'http://halal.addi.is.its.ac.id/manufactures/T_Co_Coffee_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Dawn_Bread',
#  'http://halal.addi.is.its.ac.id/manufactures/Dawn_Frozen_Foods',
#  'http://halal.addi.is.its.ac.id/manufactures/Best_Paitee_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Upfield_Malaysia_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Magna_Mission_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Star_Micro_Technology_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Enterlife_M_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Leiner_Pak',
#  'http://halal.addi.is.its.ac.id/manufactures/Sehar_Enterprises',
#  'http://halal.addi.is.its.ac.id/manufactures/Al_Khair_Creative_Quality_Ware',
#  'http://halal.addi.is.its.ac.id/manufactures/Gumcorp_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Rizkifajar_Resources',
#  'http://halal.addi.is.its.ac.id/manufactures/Try_Me_Collection_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Potential_Crest_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Great_Value',
#  'http://halal.addi.is.its.ac.id/manufactures/Fortifoods_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Fiedra_Shahora_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/Charoen_Pokphand_Pakistan_Pvt_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Golden_Harvest_Foods_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Hilal_Foods_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Tasly_Malaysia_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Akar_Tunjang_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Pepsico',
#  'http://halal.addi.is.its.ac.id/manufactures/Synarome_Manufacturing_Company_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Laksamana_Usaha_Noodle_Products_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Lotus_Vegetarian_Foodstuff_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Kimi_Ocean_Food_Industries_M_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Freshmate_Co',
#  'http://halal.addi.is.its.ac.id/manufactures/Nevgel_Malaysia_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Bell_More_Aromatics',
#  'http://halal.addi.is.its.ac.id/manufactures/Brand',
#  'http://halal.addi.is.its.ac.id/manufactures/Eighteen_World_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Ervas_Flores_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/Aspek_Mulia_Holdings_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Shield_Corporation_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Takexco_Malaysia_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/S_T_S_Prima_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Sahana_Homemades',
#  'http://halal.addi.is.its.ac.id/manufactures/Kang_Mei_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Meridian_Ingredients_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Zad_Resources_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Din_Farm_Products_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Wyeth_Pakistan_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Kk_Plaschem_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/Yang_Zhong_Capital_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Public_Palm_Oils_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/H_M_Foods',
#  'http://halal.addi.is.its.ac.id/manufactures/Mp_Prestige_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Convenience_Food_Industries_Private_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Shangrila_Pvt_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Npi_Network_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Ismail_Industries_Limited_Candyland',
#  'http://halal.addi.is.its.ac.id/manufactures/Young_S_Private_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Pak_Gelatin',
#  'http://halal.addi.is.its.ac.id/manufactures/Shakura_Pigmentation_Beauty_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Rasa_Rosz_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Quick_Food_Industries',
#  'http://halal.addi.is.its.ac.id/manufactures/Shan_Foods_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Ismail_Industries_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Asian_Food_Industries',
#  'http://halal.addi.is.its.ac.id/manufactures/Big_Hill_Worldwide_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Tasnor_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Pj_Natural_Food_Product_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Mijaya_Food_Supply',
#  'http://halal.addi.is.its.ac.id/manufactures/Zirma_Health_And_Beauty',
#  'http://halal.addi.is.its.ac.id/manufactures/Best_Bakery_Worldwide_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Chef_Hospitality_Services_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Mk_Pandan_Maju_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Cardyna_Industries_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Hogaworld_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Jubilant_Foods_Pvt_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Asna_Group',
#  'http://halal.addi.is.its.ac.id/manufactures/Yf_Forever_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Agro_19_Berhad',
#  'http://halal.addi.is.its.ac.id/manufactures/Multi_Superior_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Kim_Loong_Huat_Industries_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Tararata_Ventures',
#  'http://halal.addi.is.its.ac.id/ingredients/Cocoa_Butter',
#  'http://halal.addi.is.its.ac.id/foodproducts/Sarimi_Goreng_Rasa_Ayam_Kecap_Isi_2',
#  'http://halal.addi.is.its.ac.id/foodproducts/Indomie_Keriting_Goreng_Spesial',
#  'http://halal.addi.is.its.ac.id/manufactures/Vlasic',
#  'http://halal.addi.is.its.ac.id/manufactures/Qalbu_Ocean_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Kroger',
#  'http://halal.addi.is.its.ac.id/manufactures/Carr_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Hansen_S_Natural',
#  'http://halal.addi.is.its.ac.id/ingredients/Natural_Colourant_Caramel_Class_IE150A',
#  'http://halal.addi.is.its.ac.id/manufactures/Dermax_Super_Skin',
#  'http://halal.addi.is.its.ac.id/manufactures/Rezeki_Kaseh_Maju',
#  'http://halal.addi.is.its.ac.id/foodproducts/Enriched_Noodle_Product_Wide_Egg_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Vicks',
#  'http://halal.addi.is.its.ac.id/ingredients/Food_Colour',
#  'http://halal.addi.is.its.ac.id/ingredients/Peas',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Lemon_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Pepper',
#  'http://halal.addi.is.its.ac.id/ingredients/Calcium_Lactate',
#  'http://halal.addi.is.its.ac.id/manufactures/Vapor_Rub',
#  'http://halal.addi.is.its.ac.id/ingredients/Emulsifiers',
#  'http://halal.addi.is.its.ac.id/ingredients/Emulsified_Oil',
#  'http://halal.addi.is.its.ac.id/ingredients/White_Table_Wine',
#  'http://halal.addi.is.its.ac.id/manufactures/Eat_Smart_Snack',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Kemplang_Ikan',
#  'http://halal.addi.is.its.ac.id/manufactures/Tong_Yu_Food_Products_Corp',
#  'http://halal.addi.is.its.ac.id/ingredients/Alginic_Acid',
#  'http://halal.addi.is.its.ac.id/ingredients/Emulsifier',
#  'http://halal.addi.is.its.ac.id/foodproducts/Yakult',
#  'http://halal.addi.is.its.ac.id/manufactures/Hero',
#  'http://halal.addi.is.its.ac.id/manufactures/Herr',
#  'http://halal.addi.is.its.ac.id/manufactures/Cooksimple',
#  'http://halal.addi.is.its.ac.id/manufactures/Kabuto',
#  'http://halal.addi.is.its.ac.id/manufactures/Iries_Cafe',
#  'http://halal.addi.is.its.ac.id/manufactures/Polident',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Indosentra_Pelangi_Cibitung',
#  'http://halal.addi.is.its.ac.id/manufactures/Lucerne',
#  'http://halal.addi.is.its.ac.id/ingredients/Carrot_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Benton',
#  'http://halal.addi.is.its.ac.id/ingredients/Treenuts',
#  'http://halal.addi.is.its.ac.id/ingredients/Green_Tea_Leaves',
#  'http://halal.addi.is.its.ac.id/manufactures/Mrs_Mike_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Tabasco',
#  'http://halal.addi.is.its.ac.id/foodproducts/Papa_Puff_Corn_Puff_Mango_Pudding_Flavor',
#  'http://halal.addi.is.its.ac.id/foodproducts/Parmesean_Creamy_Chicken_Noodle_Soup',
#  'http://halal.addi.is.its.ac.id/ingredients/Acetic_Acid',
#  'http://halal.addi.is.its.ac.id/manufactures/Shibam',
#  'http://halal.addi.is.its.ac.id/ingredients/Garlic_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Polaner',
#  'http://halal.addi.is.its.ac.id/manufactures/Frosty_Boy_Australia_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Kawaii_Collagen_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/ingredients/Caramel_Color_Iv',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Coconut_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Strawberry_Extract',
#  'http://halal.addi.is.its.ac.id/ingredients/Natural_Flavors',
#  'http://halal.addi.is.its.ac.id/manufactures/Stroemann',
#  'http://halal.addi.is.its.ac.id/ingredients/Dinatrium_Inosinat',
#  'http://halal.addi.is.its.ac.id/manufactures/Bachman',
#  'http://halal.addi.is.its.ac.id/foodproducts/Chocopie_Marshmallow',
#  'http://halal.addi.is.its.ac.id/manufactures/Nabisco',
#  'http://halal.addi.is.its.ac.id/manufactures/Arid',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicken',
#  'http://halal.addi.is.its.ac.id/foodproducts/Al_Dente_Carba_Nada_Fettuccine_Noodles_Lemon_Pepper',
#  'http://halal.addi.is.its.ac.id/manufactures/Softsoap',
#  'http://halal.addi.is.its.ac.id/ingredients/AcesumfameK',
#  'http://halal.addi.is.its.ac.id/ingredients/Soy_Sauce_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Jasmine',
#  'http://halal.addi.is.its.ac.id/manufactures/Palmolive_Ajax_Dermassage',
#  'http://halal.addi.is.its.ac.id/ingredients/Seaweed_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Mcneil_Ppc',
#  'http://halal.addi.is.its.ac.id/foodproducts/Palmia_Margarin_Serbaguna',
#  'http://halal.addi.is.its.ac.id/manufactures/Kirkland_Singnature',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Emping_Pedas_Spicy_Oat_Nuts',
#  'http://halal.addi.is.its.ac.id/manufactures/Iries_Cafeaeurtm',
#  'http://halal.addi.is.its.ac.id/manufactures/Hilltop_Meats',
#  'http://halal.addi.is.its.ac.id/manufactures/Great_Ocean_Ingredients',
#  'http://halal.addi.is.its.ac.id/manufactures/Bounty',
#  'http://halal.addi.is.its.ac.id/manufactures/Zahlers',
#  'http://halal.addi.is.its.ac.id/manufactures/Pepto_Bismol',
#  'http://halal.addi.is.its.ac.id/manufactures/Arid_Xx',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Guava_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Stop_Shop',
#  'http://halal.addi.is.its.ac.id/foodproducts/Garuda_Pilus_Rasa_Pedas_Spicy_Coated_Peanuts',
#  'http://halal.addi.is.its.ac.id/manufactures/Mezzetta_Napa_Valley',
#  'http://halal.addi.is.its.ac.id/foodproducts/Extra_Wide_Egg_Noodles',
#  'http://halal.addi.is.its.ac.id/foodproducts/Marinade_Orange_Pre_Cooked_Noodles_Sauce_With_Vegetables_Toppings',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Nirwana_Lestari',
#  'http://halal.addi.is.its.ac.id/ingredients/Corn',
#  'http://halal.addi.is.its.ac.id/manufactures/Sensible_Portions',
#  'http://halal.addi.is.its.ac.id/manufactures/Claritin',
#  'http://halal.addi.is.its.ac.id/ingredients/Spanish_Mackarel',
#  'http://halal.addi.is.its.ac.id/manufactures/Babyganic',
#  'http://halal.addi.is.its.ac.id/foodproducts/Cocona_Nata_De_Coco',
#  'http://halal.addi.is.its.ac.id/manufactures/Tide',
#  'http://halal.addi.is.its.ac.id/ingredients/Bonito_Extract_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Schering_Plough',
#  'http://halal.addi.is.its.ac.id/manufactures/Silver_Platter',
#  'http://halal.addi.is.its.ac.id/manufactures/Burt',
#  'http://halal.addi.is.its.ac.id/manufactures/Charmin',
#  'http://halal.addi.is.its.ac.id/ingredients/Peanut_Paste',
#  'http://halal.addi.is.its.ac.id/ingredients/Soy_Sauce_Wheat',
#  'http://halal.addi.is.its.ac.id/ingredients/Peanut_Pasta',
#  'http://halal.addi.is.its.ac.id/ingredients/Identical_Mocca_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Nature_S_Promise_Enterprise',
#  'http://halal.addi.is.its.ac.id/ingredients/Dried_Lemon_Juice',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Benzoat',
#  'http://halal.addi.is.its.ac.id/ingredients/Oat',
#  'http://halal.addi.is.its.ac.id/ingredients/Dried_Vegetable',
#  'http://halal.addi.is.its.ac.id/manufactures/Dial',
#  'http://halal.addi.is.its.ac.id/manufactures/Golden_Grain',
#  'http://halal.addi.is.its.ac.id/manufactures/Real_Coco_Aloe',
#  'http://halal.addi.is.its.ac.id/manufactures/Hidden_Valley',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Benzoate',
#  'http://halal.addi.is.its.ac.id/manufactures/Muir_Glen',
#  'http://halal.addi.is.its.ac.id/manufactures/Air_Products_Malaysia',
#  'http://halal.addi.is.its.ac.id/manufactures/Amish_Wedding',
#  'http://halal.addi.is.its.ac.id/manufactures/Nutella',
#  'http://halal.addi.is.its.ac.id/ingredients/Soursop_Puree',
#  'http://halal.addi.is.its.ac.id/ingredients/Alpha_Tocoperol',
#  'http://halal.addi.is.its.ac.id/ingredients/Palm_Oil',
#  'http://halal.addi.is.its.ac.id/foodproducts/Khong_Gauan_Biscuits',
#  'http://halal.addi.is.its.ac.id/manufactures/Tofutti',
#  'http://halal.addi.is.its.ac.id/ingredients/Cheedar_Cheese',
#  'http://halal.addi.is.its.ac.id/manufactures/Sure',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame_Sauce',
#  'http://halal.addi.is.its.ac.id/ingredients/Herbes',
#  'http://halal.addi.is.its.ac.id/ingredients/Cacao_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Tomato_Sauce',
#  'http://halal.addi.is.its.ac.id/manufactures/Wacky_Mac',
#  'http://halal.addi.is.its.ac.id/manufactures/La_Choy',
#  'http://halal.addi.is.its.ac.id/ingredients/Taro',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Jadi_Abadi_Corak_Biscuit_Factory_Indonesia',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kokita_Combination_Chili_Relish_Mild_Sambal_Bajak_Pedas_Sedang',
#  'http://halal.addi.is.its.ac.id/manufactures/Nature_Valley',
#  'http://halal.addi.is.its.ac.id/manufactures/Schmidt',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Kaldu_Sari_Nabati_Indonesia',
#  'http://halal.addi.is.its.ac.id/ingredients/White_Chicken_Meat',
#  'http://halal.addi.is.its.ac.id/manufactures/Sudafed',
#  'http://halal.addi.is.its.ac.id/manufactures/Wayang',
#  'http://halal.addi.is.its.ac.id/manufactures/Neutrogena',
#  'http://halal.addi.is.its.ac.id/manufactures/Aqua_Fresh_Colgate_Crest_Mentadent_Oral_B_And_Reach',
#  'http://halal.addi.is.its.ac.id/manufactures/Thomas_Foods_International_Pty_Ltd_Tamworth',
#  'http://halal.addi.is.its.ac.id/manufactures/Yes',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Cashews',
#  'http://halal.addi.is.its.ac.id/manufactures/Lubriderm',
#  'http://halal.addi.is.its.ac.id/manufactures/Men_Degree',
#  'http://halal.addi.is.its.ac.id/manufactures/Essential_Choice',
#  'http://halal.addi.is.its.ac.id/ingredients/Glucono_DeltaLactone_Acidulant',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kabuto_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Brianna_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Kitkat',
#  'http://halal.addi.is.its.ac.id/ingredients/Modified_Tapioca_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Gonnella',
#  'http://halal.addi.is.its.ac.id/ingredients/Erythrosine',
#  'http://halal.addi.is.its.ac.id/manufactures/Rosniza_Coffee',
#  'http://halal.addi.is.its.ac.id/ingredients/Lecithin',
#  'http://halal.addi.is.its.ac.id/manufactures/Manischewitz',
#  'http://halal.addi.is.its.ac.id/manufactures/Heinz',
#  'http://halal.addi.is.its.ac.id/ingredients/Sweet_Potato',
#  'http://halal.addi.is.its.ac.id/manufactures/Perusahaan_Teh_Dua_Burung',
#  'http://halal.addi.is.its.ac.id/manufactures/Heb',
#  'http://halal.addi.is.its.ac.id/manufactures/B_W_Food_Products_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Head_Shoulder',
#  'http://halal.addi.is.its.ac.id/ingredients/Annatto_Turmeric',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Ultrajaya_Milk_Industry_Trading_Co_Tbk',
#  'http://halal.addi.is.its.ac.id/manufactures/Shoprite',
#  'http://halal.addi.is.its.ac.id/ingredients/Redpepper_Sweetcorn',
#  'http://halal.addi.is.its.ac.id/manufactures/Pringles',
#  'http://halal.addi.is.its.ac.id/manufactures/Cardini',
#  'http://halal.addi.is.its.ac.id/manufactures/Yunlin_Yuanchang_Poultry_Product_Coop',
#  'http://halal.addi.is.its.ac.id/manufactures/Archer_Farms',
#  'http://halal.addi.is.its.ac.id/manufactures/Farmer_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Kirk_Castile',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Makindo_Perdana',
#  'http://halal.addi.is.its.ac.id/manufactures/Safe_Gurad',
#  'http://halal.addi.is.its.ac.id/manufactures/Barcelona',
#  'http://halal.addi.is.its.ac.id/ingredients/Durm_Wheat',
#  'http://halal.addi.is.its.ac.id/manufactures/Equate',
#  'http://halal.addi.is.its.ac.id/ingredients/Peanuts',
#  'http://halal.addi.is.its.ac.id/manufactures/Fresh_Dairy',
#  'http://halal.addi.is.its.ac.id/manufactures/Aqurafresh',
#  'http://halal.addi.is.its.ac.id/ingredients/Sequestrant_Edta',
#  'http://halal.addi.is.its.ac.id/ingredients/Hydrolyzed_Soy_Protein',
#  'http://halal.addi.is.its.ac.id/ingredients/Garlic_Seasoning',
#  'http://halal.addi.is.its.ac.id/manufactures/Wholesome_Sweeteners',
#  'http://halal.addi.is.its.ac.id/foodproducts/Nutrijell_Rasa_Leci',
#  'http://halal.addi.is.its.ac.id/ingredients/Preservative_Potassium_Sorbate',
#  'http://halal.addi.is.its.ac.id/ingredients/Green_Chilli',
#  'http://halal.addi.is.its.ac.id/manufactures/Cashmere',
#  'http://halal.addi.is.its.ac.id/manufactures/Estee_Lauder',
#  'http://halal.addi.is.its.ac.id/ingredients/Nata_De_Coco',
#  'http://halal.addi.is.its.ac.id/foodproducts/Krupuk_Ubi_Kayu',
#  'http://halal.addi.is.its.ac.id/ingredients/Shallot',
#  'http://halal.addi.is.its.ac.id/manufactures/Mothers',
#  'http://halal.addi.is.its.ac.id/manufactures/Friendly_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Ka_Me',
#  'http://halal.addi.is.its.ac.id/manufactures/Casbah',
#  'http://halal.addi.is.its.ac.id/manufactures/Reach',
#  'http://halal.addi.is.its.ac.id/manufactures/Mccann_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Pampers',
#  'http://halal.addi.is.its.ac.id/foodproducts/Soy_Ginger_Noodle_Bowl_Soy_Ginger',
#  'http://halal.addi.is.its.ac.id/ingredients/Glucose_Syrup',
#  'http://halal.addi.is.its.ac.id/manufactures/Adwe_Kosher',
#  'http://halal.addi.is.its.ac.id/ingredients/Hydrolyzed_Corn_Protein',
#  'http://halal.addi.is.its.ac.id/ingredients/Rice',
#  'http://halal.addi.is.its.ac.id/manufactures/Unilever',
#  'http://halal.addi.is.its.ac.id/manufactures/Soft_Dry',
#  'http://halal.addi.is.its.ac.id/manufactures/Pirate_S_Booty',
#  'http://halal.addi.is.its.ac.id/manufactures/Brut',
#  'http://halal.addi.is.its.ac.id/manufactures/White_Rain',
#  'http://halal.addi.is.its.ac.id/manufactures/Old_Dutch',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Pandan_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Dellifood_Sentosa_Corpindo',
#  'http://halal.addi.is.its.ac.id/ingredients/Tomato',
#  'http://halal.addi.is.its.ac.id/manufactures/Mt_Olive',
#  'http://halal.addi.is.its.ac.id/manufactures/Clancy',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Mucinex',
#  'http://halal.addi.is.its.ac.id/ingredients/Konjac_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Mucines',
#  'http://halal.addi.is.its.ac.id/ingredients/Maltodextrin',
#  'http://halal.addi.is.its.ac.id/foodproducts/Noodles_Chicken',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Santos_Jaya_Abadi',
#  'http://halal.addi.is.its.ac.id/ingredients/Egg_White',
#  'http://halal.addi.is.its.ac.id/ingredients/Tartrazine',
#  'http://halal.addi.is.its.ac.id/manufactures/Speed_Stick_Lady_Speed_Stick',
#  'http://halal.addi.is.its.ac.id/ingredients/Coconut_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Vitner_S',
#  'http://halal.addi.is.its.ac.id/manufactures/V8',
#  'http://halal.addi.is.its.ac.id/foodproducts/La_Fonte_Sphagetti_10',
#  'http://halal.addi.is.its.ac.id/manufactures/Diana_Of_London',
#  'http://halal.addi.is.its.ac.id/manufactures/Zyrted',
#  'http://halal.addi.is.its.ac.id/manufactures/Nyquil',
#  'http://halal.addi.is.its.ac.id/ingredients/Spinach_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Durum_Semolina_Wheat',
#  'http://halal.addi.is.its.ac.id/manufactures/Raley_S_Everyday',
#  'http://halal.addi.is.its.ac.id/manufactures/Just_For_Men',
#  'http://halal.addi.is.its.ac.id/ingredients/Giner',
#  'http://halal.addi.is.its.ac.id/manufactures/Sweet_Baby_Ray',
#  'http://halal.addi.is.its.ac.id/manufactures/Bio_Cottage_Industry',
#  'http://halal.addi.is.its.ac.id/manufactures/Fettayleh_Wholesale_Meat_Supplies_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Vacaville',
#  'http://halal.addi.is.its.ac.id/manufactures/Kikkoman',
#  'http://halal.addi.is.its.ac.id/manufactures/Takida',
#  'http://halal.addi.is.its.ac.id/manufactures/Safeway_Select',
#  'http://halal.addi.is.its.ac.id/ingredients/Modified_Corn_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Wodonga_Rendering_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/ingredients/Durum_Wheat_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Milk_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Coconut_Water',
#  'http://halal.addi.is.its.ac.id/manufactures/Annie_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Equtae',
#  'http://halal.addi.is.its.ac.id/ingredients/Sulphite',
#  'http://halal.addi.is.its.ac.id/manufactures/Wanis_One_Marketing',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Cooked_Chicken_Meat',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Alvert',
#  'http://halal.addi.is.its.ac.id/manufactures/A_Zerega_S_Sons_Inc',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Metabisulphite',
#  'http://halal.addi.is.its.ac.id/manufactures/Dinty_Moore',
#  'http://halal.addi.is.its.ac.id/foodproducts/Jjajang_Men_Chajang_Noodle',
#  'http://halal.addi.is.its.ac.id/manufactures/Fragmin',
#  'http://halal.addi.is.its.ac.id/foodproducts/Energen_Rasa_Vanila',
#  'http://halal.addi.is.its.ac.id/manufactures/Colgate',
#  'http://halal.addi.is.its.ac.id/manufactures/A1',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame_Seed_Paste',
#  'http://halal.addi.is.its.ac.id/ingredients/Breadcrumb',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Potato_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Cascade',
#  'http://halal.addi.is.its.ac.id/manufactures/Dr_Mcdouglla_S_Right_Foods',
#  'http://halal.addi.is.its.ac.id/manufactures/Walgreens',
#  'http://halal.addi.is.its.ac.id/foodproducts/Filma_Minyak_Kelapa_Sawit',
#  'http://halal.addi.is.its.ac.id/manufactures/Diamond_Heart_Beauty',
#  'http://halal.addi.is.its.ac.id/ingredients/Extract_Of_Paprika',
#  'http://halal.addi.is.its.ac.id/ingredients/Capsanthin',
#  'http://halal.addi.is.its.ac.id/manufactures/Mrs_Cubbinson_S',
#  'http://halal.addi.is.its.ac.id/ingredients/Chili_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Soya_Bean_Extract',
#  'http://halal.addi.is.its.ac.id/manufactures/Degree',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Pondan_Pangan_Makmur_Indonesia',
#  'http://halal.addi.is.its.ac.id/ingredients/Garbanzo_Beans',
#  'http://halal.addi.is.its.ac.id/manufactures/Gbp_Australia_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Soybean',
#  'http://halal.addi.is.its.ac.id/ingredients/Whey_Oil',
#  'http://halal.addi.is.its.ac.id/ingredients/Cooking_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Shurfine',
#  'http://halal.addi.is.its.ac.id/ingredients/Soybean',
#  'http://halal.addi.is.its.ac.id/manufactures/Smucker_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Secret',
#  'http://halal.addi.is.its.ac.id/manufactures/Ryvita',
#  'http://halal.addi.is.its.ac.id/ingredients/Food_Stabilizer',
#  'http://halal.addi.is.its.ac.id/manufactures/Clover',
#  'http://halal.addi.is.its.ac.id/ingredients/Chocolate',
#  'http://halal.addi.is.its.ac.id/ingredients/Natural_Flavouring',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Marizarasa_Sarimurni_Factory_2',
#  'http://halal.addi.is.its.ac.id/manufactures/Country_Oven',
#  'http://halal.addi.is.its.ac.id/manufactures/Skippy',
#  'http://halal.addi.is.its.ac.id/ingredients/Fermented_Shrimp',
#  'http://halal.addi.is.its.ac.id/manufactures/Murphy',
#  'http://halal.addi.is.its.ac.id/manufactures/Breath_Right',
#  'http://halal.addi.is.its.ac.id/manufactures/Sa_Coffee',
#  'http://halal.addi.is.its.ac.id/manufactures/Metamucil',
#  'http://halal.addi.is.its.ac.id/manufactures/La_Victoria',
#  'http://halal.addi.is.its.ac.id/ingredients/Mushroom',
#  'http://halal.addi.is.its.ac.id/ingredients/Jasmine_Flower',
#  'http://halal.addi.is.its.ac.id/ingredients/Tapioca',
#  'http://halal.addi.is.its.ac.id/foodproducts/Indomilk',
#  'http://halal.addi.is.its.ac.id/foodproducts/Richeese_Nabati_Cheese_Wafer',
#  'http://halal.addi.is.its.ac.id/manufactures/Zantac',
#  'http://halal.addi.is.its.ac.id/manufactures/Emerald',
#  'http://halal.addi.is.its.ac.id/manufactures/Camey',
#  'http://halal.addi.is.its.ac.id/ingredients/Molasses',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Vanila_Flavour',
#  'http://halal.addi.is.its.ac.id/foodproducts/Hydro_Coco_Original',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Salim_Ivomas_Pratama_Tbk',
#  'http://halal.addi.is.its.ac.id/foodproducts/Noodles_In_Chicken_Broth_Condensed_Soup',
#  'http://halal.addi.is.its.ac.id/manufactures/Wonder',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Sena_Anugrah_Mandiri',
#  'http://halal.addi.is.its.ac.id/ingredients/Aspartame',
#  'http://halal.addi.is.its.ac.id/ingredients/Modified_Cornstarch',
#  'http://halal.addi.is.its.ac.id/manufactures/Thomas',
#  'http://halal.addi.is.its.ac.id/manufactures/Open_Pit',
#  'http://halal.addi.is.its.ac.id/foodproducts/Original_Love_Juice_Orange',
#  'http://halal.addi.is.its.ac.id/manufactures/Kelloggs',
#  'http://halal.addi.is.its.ac.id/manufactures/Dryer_S',
#  'http://halal.addi.is.its.ac.id/ingredients/Rice_Bran_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Vaseline',
#  'http://halal.addi.is.its.ac.id/manufactures/Utopia',
#  'http://halal.addi.is.its.ac.id/foodproducts/Susu_Jahe_Sidomuncul',
#  'http://halal.addi.is.its.ac.id/foodproducts/Coated_Peanuts_Garlic_Flavor_Garuda',
#  'http://halal.addi.is.its.ac.id/foodproducts/Richoco_Nabati_Chocolate_Wafer',
#  'http://halal.addi.is.its.ac.id/manufactures/Theraflu',
#  'http://halal.addi.is.its.ac.id/manufactures/Cepacol',
#  'http://halal.addi.is.its.ac.id/manufactures/Ultra_Brite',
#  'http://halal.addi.is.its.ac.id/manufactures/Sperance_Meat_Exports',
#  'http://halal.addi.is.its.ac.id/manufactures/Delmonte',
#  'http://halal.addi.is.its.ac.id/manufactures/Jif',
#  'http://halal.addi.is.its.ac.id/manufactures/Paldo_Paldo_Co_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Van_S',
#  'http://halal.addi.is.its.ac.id/foodproducts/Indomie_My_Noodlez_Rasa_Rumput_Laut',
#  'http://halal.addi.is.its.ac.id/ingredients/Niacin_Vitamin_B3',
#  'http://halal.addi.is.its.ac.id/ingredients/Chilli_Extract',
#  'http://halal.addi.is.its.ac.id/manufactures/Rainbow_Research_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Immodium',
#  'http://halal.addi.is.its.ac.id/manufactures/Cetaphil',
#  'http://halal.addi.is.its.ac.id/manufactures/Victoria_Valley_Meat_Exports_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Lotte_Indonesia',
#  'http://halal.addi.is.its.ac.id/manufactures/Dsm_Food_Specialties_Australia',
#  'http://halal.addi.is.its.ac.id/manufactures/Gillet',
#  'http://halal.addi.is.its.ac.id/manufactures/Izzara_Ziqq_Trading',
#  'http://halal.addi.is.its.ac.id/manufactures/Adams',
#  'http://halal.addi.is.its.ac.id/manufactures/Hershey',
#  'http://halal.addi.is.its.ac.id/manufactures/Gourmet_Rose',
#  'http://halal.addi.is.its.ac.id/ingredients/Onion_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Freihofer_S',
#  'http://halal.addi.is.its.ac.id/ingredients/Black_Bean',
#  'http://halal.addi.is.its.ac.id/ingredients/Corn_Strach',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kapal_Api_White_Coffee_3In1_Instant_Coffee',
#  'http://halal.addi.is.its.ac.id/ingredients/Beta_Carotene',
#  'http://halal.addi.is.its.ac.id/ingredients/Mineral',
#  'http://halal.addi.is.its.ac.id/ingredients/Lemon_Juice',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicken_Stock',
#  'http://halal.addi.is.its.ac.id/foodproducts/La_Fonte_Spaghetti_With_Mushroom_Sauce',
#  'http://halal.addi.is.its.ac.id/manufactures/Earth_Balance',
#  'http://halal.addi.is.its.ac.id/manufactures/Betty_Crocker',
#  'http://halal.addi.is.its.ac.id/foodproducts/Dancow_Susu_Bubuk_Full_Cream',
#  'http://halal.addi.is.its.ac.id/manufactures/Zest',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Forisa_Nusapersada',
#  'http://halal.addi.is.its.ac.id/foodproducts/Indofood_Bumbu_Instan_Rawon',
#  'http://halal.addi.is.its.ac.id/manufactures/Triaminic',
#  'http://halal.addi.is.its.ac.id/manufactures/Irish_Spring',
#  'http://halal.addi.is.its.ac.id/manufactures/Prairie_Farm',
#  'http://halal.addi.is.its.ac.id/ingredients/Egg_Yolks_Or_Eggs',
#  'http://halal.addi.is.its.ac.id/manufactures/Sundae_Shoppe',
#  'http://halal.addi.is.its.ac.id/ingredients/Calium_Sorbate',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Sweetener_Sucralose',
#  'http://halal.addi.is.its.ac.id/foodproducts/Ramen_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Sunshine',
#  'http://halal.addi.is.its.ac.id/ingredients/Spice',
#  'http://halal.addi.is.its.ac.id/manufactures/Gold',
#  'http://halal.addi.is.its.ac.id/manufactures/Contact',
#  'http://halal.addi.is.its.ac.id/manufactures/Straus',
#  'http://halal.addi.is.its.ac.id/manufactures/Paradise_Meadow',
#  'http://halal.addi.is.its.ac.id/ingredients/Natural_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Bell_Pepper',
#  'http://halal.addi.is.its.ac.id/manufactures/Ban',
#  'http://halal.addi.is.its.ac.id/ingredients/Anticacking',
#  'http://halal.addi.is.its.ac.id/ingredients/Sea_Salt',
#  'http://halal.addi.is.its.ac.id/manufactures/Tums',
#  'http://halal.addi.is.its.ac.id/ingredients/Edible_Vegetable_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Knudson',
#  'http://halal.addi.is.its.ac.id/manufactures/Nature_S_Harvest',
#  'http://halal.addi.is.its.ac.id/ingredients/Shiitake_Mushroom',
#  'http://halal.addi.is.its.ac.id/ingredients/Flavoring',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Industri_Jamu_Farmasi_Sidomuncul',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicken_Fat',
#  'http://halal.addi.is.its.ac.id/manufactures/Finis',
#  'http://halal.addi.is.its.ac.id/manufactures/Planters',
#  'http://halal.addi.is.its.ac.id/manufactures/Pd_Setia_Makmur_Mandiri',
#  'http://halal.addi.is.its.ac.id/ingredients/Tamarind',
#  'http://halal.addi.is.its.ac.id/manufactures/Norrich_Resources',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Mayora_Indah_Tbk',
#  'http://halal.addi.is.its.ac.id/ingredients/Pasteurized_Whole_Eggs',
#  'http://halal.addi.is.its.ac.id/manufactures/Ottogi',
#  'http://halal.addi.is.its.ac.id/manufactures/D_Italiano',
#  'http://halal.addi.is.its.ac.id/ingredients/Rose_Flavor',
#  'http://halal.addi.is.its.ac.id/manufactures/Nutra_Molecular',
#  'http://halal.addi.is.its.ac.id/ingredients/Chocolate_Artificial_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Artifical_Color',
#  'http://halal.addi.is.its.ac.id/manufactures/Cemara_Dakti_Trade_Center',
#  'http://halal.addi.is.its.ac.id/manufactures/Manity_Enterprise',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kokita_Sambal_Terasi_Blacan_Chili_Relish',
#  'http://halal.addi.is.its.ac.id/foodproducts/Sena_Roasted_Fish_Crackers',
#  'http://halal.addi.is.its.ac.id/manufactures/Midol',
#  'http://halal.addi.is.its.ac.id/ingredients/Peanut',
#  'http://halal.addi.is.its.ac.id/manufactures/Natural_Oven',
#  'http://halal.addi.is.its.ac.id/ingredients/Selected_Peanuts',
#  'http://halal.addi.is.its.ac.id/manufactures/New_York',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Unimos',
#  'http://halal.addi.is.its.ac.id/manufactures/Z_Raudah',
#  'http://halal.addi.is.its.ac.id/manufactures/Sunsweet',
#  'http://halal.addi.is.its.ac.id/ingredients/Kelp_Extract_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Western',
#  'http://halal.addi.is.its.ac.id/manufactures/Kerry_Gold',
#  'http://halal.addi.is.its.ac.id/manufactures/Herbal_Essence',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Roast_Chicken_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Onion',
#  'http://halal.addi.is.its.ac.id/manufactures/Foulds',
#  'http://halal.addi.is.its.ac.id/ingredients/Thickener_And_Colouring',
#  'http://halal.addi.is.its.ac.id/manufactures/Pond_S',
#  'http://halal.addi.is.its.ac.id/ingredients/Buttermilk_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Carnation',
#  'http://halal.addi.is.its.ac.id/manufactures/Mitchum',
#  'http://halal.addi.is.its.ac.id/manufactures/Grey_Poupon',
#  'http://halal.addi.is.its.ac.id/ingredients/Enzyme',
#  'http://halal.addi.is.its.ac.id/manufactures/Colgate_Palmolive',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicken_Meat',
#  'http://halal.addi.is.its.ac.id/manufactures/Aunt_Millie_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Ball_Park',
#  'http://halal.addi.is.its.ac.id/ingredients/Niacin',
#  'http://halal.addi.is.its.ac.id/ingredients/Ginger',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Chili_Pepper',
#  'http://halal.addi.is.its.ac.id/ingredients/Caramel',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Lychee_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Dried_Shrimp',
#  'http://halal.addi.is.its.ac.id/ingredients/Black_Soybean',
#  'http://halal.addi.is.its.ac.id/manufactures/Aneka_Citra_Snack',
#  'http://halal.addi.is.its.ac.id/ingredients/Extractives_Of_Paprika_Color',
#  'http://halal.addi.is.its.ac.id/ingredients/Bbq',
#  'http://halal.addi.is.its.ac.id/ingredients/Hydrolized_Milk_Protein',
#  'http://halal.addi.is.its.ac.id/manufactures/Village_Hearth',
#  'http://halal.addi.is.its.ac.id/ingredients/Soya_Oil',
#  'http://halal.addi.is.its.ac.id/ingredients/Corn_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Galbani',
#  'http://halal.addi.is.its.ac.id/manufactures/Fred_Meyer',
#  'http://halal.addi.is.its.ac.id/ingredients/Ferrous_Sulfate_Iron',
#  'http://halal.addi.is.its.ac.id/ingredients/Reduced_Iron',
#  'http://halal.addi.is.its.ac.id/manufactures/Simply_Nature',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Whiite_Cappuccino_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Mother_S',
#  'http://halal.addi.is.its.ac.id/ingredients/B2',
#  'http://halal.addi.is.its.ac.id/ingredients/B6',
#  'http://halal.addi.is.its.ac.id/foodproducts/Minute_Maid_Pulpy_Aloe_Vera_White_Grape',
#  'http://halal.addi.is.its.ac.id/ingredients/Instant_Coffee',
#  'http://halal.addi.is.its.ac.id/manufactures/Dean',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Rice_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Banana_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Antioxidant_Ascorbyl_Palmitate',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Tiramisu_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Disodium_Guanylate',
#  'http://halal.addi.is.its.ac.id/manufactures/Pennsylvania_Dutch',
#  'http://halal.addi.is.its.ac.id/manufactures/Stauffers',
#  'http://halal.addi.is.its.ac.id/manufactures/Richman_Vision_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Keripik_Makaroni_Macaroni_Crisps',
#  'http://halal.addi.is.its.ac.id/manufactures/4C',
#  'http://halal.addi.is.its.ac.id/manufactures/Smart_Puffs',
#  'http://halal.addi.is.its.ac.id/ingredients/Malt',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetable_Stabilizer',
#  'http://halal.addi.is.its.ac.id/manufactures/St_Joseph',
#  'http://halal.addi.is.its.ac.id/ingredients/Coconut_Gel',
#  'http://halal.addi.is.its.ac.id/manufactures/Special_K',
#  'http://halal.addi.is.its.ac.id/manufactures/Garden_Of_Eatin',
#  'http://halal.addi.is.its.ac.id/ingredients/Canola_Oil',
#  'http://halal.addi.is.its.ac.id/ingredients/Semolina_And_Durum_Flour_Wheat',
#  'http://halal.addi.is.its.ac.id/manufactures/Aquafresh',
#  'http://halal.addi.is.its.ac.id/manufactures/Fr_Enterprise',
#  'http://halal.addi.is.its.ac.id/manufactures/Scott',
#  'http://halal.addi.is.its.ac.id/ingredients/Spices',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Egg_White',
#  'http://halal.addi.is.its.ac.id/manufactures/Savoritz',
#  'http://halal.addi.is.its.ac.id/foodproducts/Frisian_Flag_Pure_Farm',
#  'http://halal.addi.is.its.ac.id/ingredients/Malt_Extract',
#  'http://halal.addi.is.its.ac.id/foodproducts/Dr_Mcdougall_S_Right_Foods_Vegan_Noodle_Soup_Chicken',
#  'http://halal.addi.is.its.ac.id/manufactures/Jergen',
#  'http://halal.addi.is.its.ac.id/manufactures/Cedar_Meats_Aust_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Telur_Gabus_Sweet_Cookies',
#  'http://halal.addi.is.its.ac.id/ingredients/Potassium_Chloride',
#  'http://halal.addi.is.its.ac.id/manufactures/Amin_Production',
#  'http://halal.addi.is.its.ac.id/ingredients/Onjon',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kokita_Combination_Chilli_Relish_Hot_Sambal_Bajak',
#  'http://halal.addi.is.its.ac.id/ingredients/Black_Pepper',
#  'http://halal.addi.is.its.ac.id/manufactures/Koepplinger_S',
#  'http://halal.addi.is.its.ac.id/foodproducts/Pazar_Sambal_Terasi_Original',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Yakult_Indonesia_Persada',
#  'http://halal.addi.is.its.ac.id/foodproducts/Sirup_Marjan_Rasa_Ros',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Kerupuk_Fish_Ball_Fish_Ball_Cracker_Getes',
#  'http://halal.addi.is.its.ac.id/foodproducts/So_Good_Chicken_Stick_Premium',
#  'http://halal.addi.is.its.ac.id/manufactures/Right_Guard',
#  'http://halal.addi.is.its.ac.id/ingredients/Carrots',
#  'http://halal.addi.is.its.ac.id/ingredients/Orange_Juice_Concentrate',
#  'http://halal.addi.is.its.ac.id/ingredients/Tapioca_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Dehydrated_Seaweed',
#  'http://halal.addi.is.its.ac.id/manufactures/Afrin',
#  'http://halal.addi.is.its.ac.id/manufactures/Wheat_Thins',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame',
#  'http://halal.addi.is.its.ac.id/manufactures/Greenway',
#  'http://halal.addi.is.its.ac.id/manufactures/Curel',
#  'http://halal.addi.is.its.ac.id/foodproducts/Soba_Stir_Fry_Noodles',
#  'http://halal.addi.is.its.ac.id/ingredients/Whole_Egg_Liquid',
#  'http://halal.addi.is.its.ac.id/manufactures/Girard_S',
#  'http://halal.addi.is.its.ac.id/foodproducts/Tao_Kae_Noi_Crispy_Seaweed_Big_Sheet',
#  'http://halal.addi.is.its.ac.id/manufactures/Scope',
#  'http://halal.addi.is.its.ac.id/ingredients/Vital_Wheat_Gluten',
#  'http://halal.addi.is.its.ac.id/ingredients/Mononitrate_Vitamin_B1',
#  'http://halal.addi.is.its.ac.id/ingredients/Riboflavin',
#  'http://halal.addi.is.its.ac.id/ingredients/Preservative',
#  'http://halal.addi.is.its.ac.id/ingredients/Sesame_Seed',
#  'http://halal.addi.is.its.ac.id/manufactures/Old_Spice',
#  'http://halal.addi.is.its.ac.id/manufactures/Central_Meat_Exports_Pty_Ltd_Boning_Room_Only',
#  'http://halal.addi.is.its.ac.id/manufactures/Walgreen',
#  'http://halal.addi.is.its.ac.id/manufactures/Phillips',
#  'http://halal.addi.is.its.ac.id/manufactures/Garcinia_Cambogia',
#  'http://halal.addi.is.its.ac.id/manufactures/Hokubee_Australia_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/manufactures/The_Snack_Artist',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Indolakto',
#  'http://halal.addi.is.its.ac.id/manufactures/The_Body_Shop',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Keripik_Pisang_Sale_Lidah_Banana_Crisps',
#  'http://halal.addi.is.its.ac.id/manufactures/Friendship',
#  'http://halal.addi.is.its.ac.id/manufactures/Amy_S_Amy_S_Kitchen_Inc',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic',
#  'http://halal.addi.is.its.ac.id/manufactures/Newman_S_Own',
#  'http://halal.addi.is.its.ac.id/ingredients/Yeast_Extract',
#  'http://halal.addi.is.its.ac.id/manufactures/Juice_Beauty',
#  'http://halal.addi.is.its.ac.id/ingredients/Vitamin_Premix_B1',
#  'http://halal.addi.is.its.ac.id/manufactures/Metropolitan',
#  'http://halal.addi.is.its.ac.id/ingredients/Skim_Milk_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Eggs',
#  'http://halal.addi.is.its.ac.id/manufactures/Polly_O',
#  'http://halal.addi.is.its.ac.id/manufactures/Kaedama',
#  'http://halal.addi.is.its.ac.id/foodproducts/Tango_Susu_Vanilla',
#  'http://halal.addi.is.its.ac.id/ingredients/Non_Diary_Creamer',
#  'http://halal.addi.is.its.ac.id/manufactures/Chloraseptic',
#  'http://halal.addi.is.its.ac.id/foodproducts/Astor_Wafer_Stick_Cokelat',
#  'http://halal.addi.is.its.ac.id/manufactures/Perfect_Food_Products_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/manufactures/Friendly',
#  'http://halal.addi.is.its.ac.id/ingredients/Seaweed',
#  'http://halal.addi.is.its.ac.id/ingredients/Milk_Protein_Concentrate',
#  'http://halal.addi.is.its.ac.id/ingredients/Battermix_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Friendly_Farm',
#  'http://halal.addi.is.its.ac.id/ingredients/Stabilizer_Xanthan_Gum',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetable_Fat',
#  'http://halal.addi.is.its.ac.id/manufactures/Km_Power',
#  'http://halal.addi.is.its.ac.id/ingredients/Beef_Soup_Stock',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Gunacipta_Multirasa',
#  'http://halal.addi.is.its.ac.id/ingredients/Fish',
#  'http://halal.addi.is.its.ac.id/ingredients/Lecitin',
#  'http://halal.addi.is.its.ac.id/manufactures/Kern_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Aleve',
#  'http://halal.addi.is.its.ac.id/manufactures/Colonial',
#  'http://halal.addi.is.its.ac.id/foodproducts/Pho_Soup_Rice_Noodle_Soup_With_Herbs_And_Beef',
#  'http://halal.addi.is.its.ac.id/manufactures/Listerine',
#  'http://halal.addi.is.its.ac.id/manufactures/365_Bar_Soap_Whole_Food_Market',
#  'http://halal.addi.is.its.ac.id/ingredients/Stabilizer',
#  'http://halal.addi.is.its.ac.id/manufactures/Lupin',
#  'http://halal.addi.is.its.ac.id/foodproducts/Al_Dente_Three_Pepper_Fettuccine_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Market_Pantry',
#  'http://halal.addi.is.its.ac.id/manufactures/Aveeno',
#  'http://halal.addi.is.its.ac.id/ingredients/Roasted_Layer',
#  'http://halal.addi.is.its.ac.id/ingredients/Corn_Starch_Syrup',
#  'http://halal.addi.is.its.ac.id/ingredients/Onion',
#  'http://halal.addi.is.its.ac.id/manufactures/Universal_Food',
#  'http://halal.addi.is.its.ac.id/foodproducts/Energen_Susu_Cereal_Rasa_Jahe',
#  'http://halal.addi.is.its.ac.id/foodproducts/Majorico_Wafer_Roll_Rasa_Pisang_Coklat',
#  'http://halal.addi.is.its.ac.id/ingredients/Sunset_Yellow_Fcf',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Vanilin_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Autolyzed_Yeast_Extract',
#  'http://halal.addi.is.its.ac.id/manufactures/Essentially_Yours',
#  'http://halal.addi.is.its.ac.id/foodproducts/Margarine_Forvita',
#  'http://halal.addi.is.its.ac.id/manufactures/Utz',
#  'http://halal.addi.is.its.ac.id/foodproducts/Dandan_Noodle_Flavoring',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Carbonate',
#  'http://halal.addi.is.its.ac.id/foodproducts/La_Fonte_Pronto_Spaghetti_With_Chicken_Sauce',
#  'http://halal.addi.is.its.ac.id/ingredients/Cornstarch',
#  'http://halal.addi.is.its.ac.id/manufactures/Aakash_Yog_Health_Products_Private_Limited',
#  'http://halal.addi.is.its.ac.id/manufactures/Vick',
#  'http://halal.addi.is.its.ac.id/ingredients/Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Spaghetti',
#  'http://halal.addi.is.its.ac.id/manufactures/Happy_Farms',
#  'http://halal.addi.is.its.ac.id/foodproducts/Cap_Ibu_Sambal_Bajak_Indonesia_Combiation_Chili_Relish',
#  'http://halal.addi.is.its.ac.id/manufactures/Suria_Hallia_Sdn_Bhd',
#  'http://halal.addi.is.its.ac.id/ingredients/Brilliant_Blue_Fcf',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Inaco_Food',
#  'http://halal.addi.is.its.ac.id/ingredients/Candlenut',
#  'http://halal.addi.is.its.ac.id/ingredients/Sherry_Wine_Solids',
#  'http://halal.addi.is.its.ac.id/manufactures/Ex_Lax',
#  'http://halal.addi.is.its.ac.id/manufactures/Terra',
#  'http://halal.addi.is.its.ac.id/ingredients/Gelatin',
#  'http://halal.addi.is.its.ac.id/manufactures/Pert',
#  'http://halal.addi.is.its.ac.id/ingredients/Lime_Leaf',
#  'http://halal.addi.is.its.ac.id/ingredients/Mango',
#  'http://halal.addi.is.its.ac.id/manufactures/Speed_Stick',
#  'http://halal.addi.is.its.ac.id/manufactures/Icy_Hot',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Bina_Karya_Prima',
#  'http://halal.addi.is.its.ac.id/manufactures/Chun_Yuen_Trading_Co',
#  'http://halal.addi.is.its.ac.id/ingredients/Potassium_Sorbate',
#  'http://halal.addi.is.its.ac.id/manufactures/Mccafe',
#  'http://halal.addi.is.its.ac.id/ingredients/Water',
#  'http://halal.addi.is.its.ac.id/ingredients/Shortening',
#  'http://halal.addi.is.its.ac.id/foodproducts/Spinach_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/French',
#  'http://halal.addi.is.its.ac.id/manufactures/Pedia_Sure',
#  'http://halal.addi.is.its.ac.id/manufactures/Eos',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Kalbe',
#  'http://halal.addi.is.its.ac.id/foodproducts/Pondan_Pukis_Cake_Mix',
#  'http://halal.addi.is.its.ac.id/ingredients/Semolina',
#  'http://halal.addi.is.its.ac.id/manufactures/Vel',
#  'http://halal.addi.is.its.ac.id/ingredients/Flavorings',
#  'http://halal.addi.is.its.ac.id/foodproducts/Cap_Ibu_Sambal_Kecap_Sweet_Soy_Chili_Sauce_Hot',
#  'http://halal.addi.is.its.ac.id/ingredients/Annato',
#  'http://halal.addi.is.its.ac.id/manufactures/Sustainably_Harvest',
#  'http://halal.addi.is.its.ac.id/ingredients/Celeriac_Concentration',
#  'http://halal.addi.is.its.ac.id/ingredients/Coconut_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicken_Broth',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Ultra_Prima_Abadi',
#  'http://halal.addi.is.its.ac.id/foodproducts/Blue_Band',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetable_Stabilizerand_Sodium_Polyphospate',
#  'http://halal.addi.is.its.ac.id/ingredients/Saybean',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Soursop_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Chilli_Pepper_Paste',
#  'http://halal.addi.is.its.ac.id/ingredients/Milk_Chocolate',
#  'http://halal.addi.is.its.ac.id/ingredients/Celery_Juice_Concentrate',
# ...
#  'http://halal.addi.is.its.ac.id/manufactures/Coast',
#  'http://halal.addi.is.its.ac.id/manufactures/Bonne_Mamam',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Orange_Flavour',
#  'http://halal.addi.is.its.ac.id/ingredients/Melon_Concentrate_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Amonium_Bicarbonate',
#  'http://halal.addi.is.its.ac.id/manufactures/Kleenex',
#  'http://halal.addi.is.its.ac.id/manufactures/Revlon',
#  'http://halal.addi.is.its.ac.id/foodproducts/Tango_Wafer_Kraffel_Original_Sweet',
#  'http://halal.addi.is.its.ac.id/manufactures/Yurill_Enterprise',
#  'http://halal.addi.is.its.ac.id/ingredients/Mango_Flavor',
#  'http://halal.addi.is.its.ac.id/ingredients/Leavening_Agent',
#  'http://halal.addi.is.its.ac.id/manufactures/Robitussin',
#  'http://halal.addi.is.its.ac.id/ingredients/Malic_Acid',
#  'http://halal.addi.is.its.ac.id/ingredients/Carmoisine',
#  'http://halal.addi.is.its.ac.id/ingredients/Lactosa',
#  'http://halal.addi.is.its.ac.id/manufactures/Lady_Speed',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Flavouring',
#  'http://halal.addi.is.its.ac.id/manufactures/Parmalat',
#  'http://halal.addi.is.its.ac.id/manufactures/Dr_Mcdougall_S_Right_Foods',
#  'http://halal.addi.is.its.ac.id/manufactures/Thomas_Foods_International_Murray_Bridge_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/ingredients/Milk_Solid',
#  'http://halal.addi.is.its.ac.id/manufactures/Halls',
#  'http://halal.addi.is.its.ac.id/manufactures/Roundy_S',
#  'http://halal.addi.is.its.ac.id/manufactures/Darul_Furqon',
#  'http://halal.addi.is.its.ac.id/manufactures/Go_Go_Squeeze',
#  'http://halal.addi.is.its.ac.id/ingredients/Rice_Wine',
#  'http://halal.addi.is.its.ac.id/ingredients/Potato_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Vanquish',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Nissin_Biscuit_Indonesia',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Poliphospate',
#  'http://halal.addi.is.its.ac.id/foodproducts/Abc_Minuman_Sari_Kedelai',
#  'http://halal.addi.is.its.ac.id/manufactures/Sara_Lee',
#  'http://halal.addi.is.its.ac.id/foodproducts/Ultra_Milk_Rasa_Stroberi',
#  'http://halal.addi.is.its.ac.id/ingredients/Mixed_Tocopherol',
#  'http://halal.addi.is.its.ac.id/manufactures/Red_Gold',
#  'http://halal.addi.is.its.ac.id/ingredients/Galangal',
#  'http://halal.addi.is.its.ac.id/manufactures/Arm_Hammer',
#  'http://halal.addi.is.its.ac.id/ingredients/Tapioca_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Aussie',
#  'http://halal.addi.is.its.ac.id/manufactures/Jewel',
#  'http://halal.addi.is.its.ac.id/ingredients/Vinegar',
#  'http://halal.addi.is.its.ac.id/ingredients/Strawbery_Natural_Identical_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/Dare',
#  'http://halal.addi.is.its.ac.id/foodproducts/Dua_Kelinci_Hot_Nut_Chili_Flavor_Kacang_Ala_Hawaii',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Vinegar',
#  'http://halal.addi.is.its.ac.id/ingredients/Lemon_Grass_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Downy',
#  'http://halal.addi.is.its.ac.id/manufactures/Honeyville',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Arnott_S_Indonesia',
#  'http://halal.addi.is.its.ac.id/manufactures/Countryside_Creamery',
#  'http://halal.addi.is.its.ac.id/manufactures/Miralisa_Richwealth_Plt',
#  'http://halal.addi.is.its.ac.id/manufactures/Afterglow',
#  'http://halal.addi.is.its.ac.id/ingredients/Orange_Juice',
#  'http://halal.addi.is.its.ac.id/ingredients/Flavour_Enhacer',
#  'http://halal.addi.is.its.ac.id/manufactures/Benadryl',
#  'http://halal.addi.is.its.ac.id/ingredients/Calcium_Chloride',
#  'http://halal.addi.is.its.ac.id/ingredients/Black_Bean_Paste',
#  'http://halal.addi.is.its.ac.id/ingredients/Premiks',
#  'http://halal.addi.is.its.ac.id/manufactures/Barbasol',
#  'http://halal.addi.is.its.ac.id/manufactures/Bertolli',
#  'http://halal.addi.is.its.ac.id/manufactures/Lesser_Evil',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetable_Creamer',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Wheat_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Egg',
#  'http://halal.addi.is.its.ac.id/manufactures/Elsa_Shine_Beauty',
#  'http://halal.addi.is.its.ac.id/manufactures/Neosporin',
#  'http://halal.addi.is.its.ac.id/manufactures/Mccormic',
#  'http://halal.addi.is.its.ac.id/ingredients/Orange_Pulp',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Chicken_Broth_Concentrate',
#  'http://halal.addi.is.its.ac.id/ingredients/Egg_Yolks',
#  'http://halal.addi.is.its.ac.id/manufactures/Abbotsford_Farm',
#  'http://halal.addi.is.its.ac.id/manufactures/Zraudah_Marketing',
#  'http://halal.addi.is.its.ac.id/manufactures/Waikiki',
#  'http://halal.addi.is.its.ac.id/manufactures/Marzetti',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kabuto_Rice_Noodles_Chicken_Pho_Gluten_Free',
#  'http://halal.addi.is.its.ac.id/ingredients/Starch',
#  'http://halal.addi.is.its.ac.id/ingredients/Red_Chilli',
#  'http://halal.addi.is.its.ac.id/ingredients/Durum_Semolina',
#  'http://halal.addi.is.its.ac.id/ingredients/Thiamin_Mononitrate',
#  'http://halal.addi.is.its.ac.id/manufactures/Baker_S_Corner',
#  'http://halal.addi.is.its.ac.id/foodproducts/Sidomuncul_Kopi_Jahe',
#  'http://halal.addi.is.its.ac.id/ingredients/Aloe_Vera',
#  'http://halal.addi.is.its.ac.id/manufactures/White_House',
#  'http://halal.addi.is.its.ac.id/manufactures/Ecotrin',
#  'http://halal.addi.is.its.ac.id/manufactures/Sunbeam',
#  'http://halal.addi.is.its.ac.id/manufactures/Vidal_Sassoon',
#  'http://halal.addi.is.its.ac.id/ingredients/TertButylhydroquinone',
#  'http://halal.addi.is.its.ac.id/manufactures/Von_S',
#  'http://halal.addi.is.its.ac.id/ingredients/Calcium_Sorbate',
#  'http://halal.addi.is.its.ac.id/manufactures/Country_Hearth',
#  'http://halal.addi.is.its.ac.id/manufactures/Plugra',
#  'http://halal.addi.is.its.ac.id/foodproducts/Ultra_Milk_Plain',
#  'http://halal.addi.is.its.ac.id/ingredients/Tauco',
#  'http://halal.addi.is.its.ac.id/manufactures/Rahsia_Rimba',
#  'http://halal.addi.is.its.ac.id/ingredients/Picung_Nut',
#  'http://halal.addi.is.its.ac.id/manufactures/Zara_Insyirah_Shop',
#  'http://halal.addi.is.its.ac.id/manufactures/Tessalon',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetable_Protein',
#  'http://halal.addi.is.its.ac.id/manufactures/Mrs_Baird',
#  'http://halal.addi.is.its.ac.id/ingredients/Soybean_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Wise',
#  'http://halal.addi.is.its.ac.id/ingredients/Lemon_Oil',
#  'http://halal.addi.is.its.ac.id/manufactures/Syarabu_Sihat',
#  'http://halal.addi.is.its.ac.id/ingredients/Leek_Chipc',
#  'http://halal.addi.is.its.ac.id/ingredients/Skimmed_Milk',
#  'http://halal.addi.is.its.ac.id/ingredients/Garlic_Extract',
#  'http://halal.addi.is.its.ac.id/ingredients/Parsley_Flakes',
#  'http://halal.addi.is.its.ac.id/ingredients/Calcium_Phosphate',
#  'http://halal.addi.is.its.ac.id/ingredients/Modified_Food_Starch',
#  'http://halal.addi.is.its.ac.id/manufactures/Gillette',
#  'http://halal.addi.is.its.ac.id/foodproducts/Tropicana_Slim_Nutty_Chocolate',
#  'http://halal.addi.is.its.ac.id/ingredients/Calcium',
#  'http://halal.addi.is.its.ac.id/ingredients/Nature_Identical_Flavour_Milk',
#  'http://halal.addi.is.its.ac.id/manufactures/Archway',
#  'http://halal.addi.is.its.ac.id/manufactures/Old_London',
#  'http://halal.addi.is.its.ac.id/foodproducts/Wafer_Selamat_Chocolate',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Phosphate',
#  'http://halal.addi.is.its.ac.id/manufactures/Uncle_Sam',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Chloride',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Torabika_Eka_Semesta',
#  'http://halal.addi.is.its.ac.id/ingredients/Butter',
#  'http://halal.addi.is.its.ac.id/ingredients/Paprika',
#  'http://halal.addi.is.its.ac.id/ingredients/Flavour_Enhancer',
#  'http://halal.addi.is.its.ac.id/ingredients/Gellan_Gum',
#  'http://halal.addi.is.its.ac.id/manufactures/Crest_Pro_Health',
#  'http://halal.addi.is.its.ac.id/manufactures/Turano',
#  'http://halal.addi.is.its.ac.id/manufactures/Crest',
#  'http://halal.addi.is.its.ac.id/ingredients/Celery',
#  'http://halal.addi.is.its.ac.id/ingredients/Yeast',
#  'http://halal.addi.is.its.ac.id/manufactures/Soft_Soap',
#  'http://halal.addi.is.its.ac.id/ingredients/Driedmilk',
#  'http://halal.addi.is.its.ac.id/manufactures/Ritz',
#  'http://halal.addi.is.its.ac.id/ingredients/Butylated_Hydroxyanisole',
#  'http://halal.addi.is.its.ac.id/ingredients/Bean_Sprout',
#  'http://halal.addi.is.its.ac.id/manufactures/Value_Time',
#  'http://halal.addi.is.its.ac.id/manufactures/Eida_Hassan_Pretty_Shop',
#  'http://halal.addi.is.its.ac.id/manufactures/Johnson_Johnson',
#  'http://halal.addi.is.its.ac.id/manufactures/Cabot',
#  'http://halal.addi.is.its.ac.id/ingredients/Kaffir_Lime_Leaf',
#  'http://halal.addi.is.its.ac.id/manufactures/Outshine',
#  'http://halal.addi.is.its.ac.id/ingredients/Rice_Noodles_Flour',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Monde_Mahkota_Biskuit',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Soy_Flour',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Monysaga_Prima',
#  'http://halal.addi.is.its.ac.id/ingredients/Filtered_Water',
#  'http://halal.addi.is.its.ac.id/manufactures/Sucrets',
#  'http://halal.addi.is.its.ac.id/ingredients/Riboflavin_Vitamin_B2',
#  'http://halal.addi.is.its.ac.id/foodproducts/Migelas_Protevit_Rasa_Ayam_Bawang',
#  'http://halal.addi.is.its.ac.id/ingredients/Chili_Pepper',
#  'http://halal.addi.is.its.ac.id/ingredients/Ginger_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Lance',
#  'http://halal.addi.is.its.ac.id/manufactures/Nature_S_Own',
#  'http://halal.addi.is.its.ac.id/ingredients/Organic_Whole_Egg',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Asiacapital_Utama_Indonesia',
#  'http://halal.addi.is.its.ac.id/manufactures/Millville',
#  'http://halal.addi.is.its.ac.id/manufactures/King_S_Hawaiin',
#  'http://halal.addi.is.its.ac.id/foodproducts/Thai_Inspired_Rice_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Badger',
#  'http://halal.addi.is.its.ac.id/ingredients/Bleached_Wheat_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Chicnken_Broth',
#  'http://halal.addi.is.its.ac.id/ingredients/Ferrous_Sulfate',
#  'http://halal.addi.is.its.ac.id/manufactures/Love_N_Fresh',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_General_Food_Industries_Bandung',
#  'http://halal.addi.is.its.ac.id/manufactures/Sensodyne',
#  'http://halal.addi.is.its.ac.id/manufactures/Natrel',
#  'http://halal.addi.is.its.ac.id/manufactures/Pulmuone',
#  'http://halal.addi.is.its.ac.id/manufactures/R_W_Knudsen',
#  'http://halal.addi.is.its.ac.id/manufactures/Veet',
#  'http://halal.addi.is.its.ac.id/manufactures/Flowershop',
#  'http://halal.addi.is.its.ac.id/ingredients/Preservative_Sodium_Benzoate',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Smart_Tbk',
#  'http://halal.addi.is.its.ac.id/ingredients/Lemon',
#  'http://halal.addi.is.its.ac.id/manufactures/Mission',
#  'http://halal.addi.is.its.ac.id/manufactures/Kansas_City_Masterpiece',
#  'http://halal.addi.is.its.ac.id/manufactures/Scotch_Brite',
#  'http://halal.addi.is.its.ac.id/manufactures/Signature_Kitchens',
#  'http://halal.addi.is.its.ac.id/foodproducts/Made_With_Organic_Noodles_Asian_Noodles_Spicy_Szechuan',
#  'http://halal.addi.is.its.ac.id/ingredients/Chocolate_Flavour',
#  'http://halal.addi.is.its.ac.id/manufactures/La_Fortaleza',
#  'http://halal.addi.is.its.ac.id/ingredients/Chilli',
#  'http://halal.addi.is.its.ac.id/manufactures/Jack_Daniels',
#  'http://halal.addi.is.its.ac.id/foodproducts/Silver_Queen_Chunky_Bar',
#  'http://halal.addi.is.its.ac.id/manufactures/Simply_Asia',
#  'http://halal.addi.is.its.ac.id/manufactures/Miracle_Whip',
#  'http://halal.addi.is.its.ac.id/ingredients/Wheat',
#  'http://halal.addi.is.its.ac.id/ingredients/Sodium_Bicarbonate',
#  'http://halal.addi.is.its.ac.id/ingredients/Plum_Sauce',
#  'http://halal.addi.is.its.ac.id/foodproducts/Tong_Tji_Jasmine_Green_Tea',
#  'http://halal.addi.is.its.ac.id/ingredients/Shrimp',
#  'http://halal.addi.is.its.ac.id/foodproducts/Sambal_Terasi_Uleg',
#  'http://halal.addi.is.its.ac.id/ingredients/Sucrose',
#  'http://halal.addi.is.its.ac.id/ingredients/Maltodextrine',
#  'http://halal.addi.is.its.ac.id/manufactures/Zican',
#  'http://halal.addi.is.its.ac.id/ingredients/Ammonium_Bicarbonate',
#  'http://halal.addi.is.its.ac.id/ingredients/Artificial_Flavour',
#  'http://halal.addi.is.its.ac.id/foodproducts/Garlic_Parsley_Noodles',
#  'http://halal.addi.is.its.ac.id/ingredients/Bean',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Keripik_Tempe_Soy_Bean_Crips',
#  'http://halal.addi.is.its.ac.id/ingredients/Beef_Extract_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Coriander_Powder',
#  'http://halal.addi.is.its.ac.id/manufactures/Axelrod',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Jeinz_Abc_Indonesia',
#  'http://halal.addi.is.its.ac.id/ingredients/Vegetables_Protein_Flake',
#  'http://halal.addi.is.its.ac.id/manufactures/Edge',
#  'http://halal.addi.is.its.ac.id/ingredients/Mungbean_Juice',
#  'http://halal.addi.is.its.ac.id/ingredients/Brown_Sugar',
#  'http://halal.addi.is.its.ac.id/foodproducts/Mie_Abc_Selera_Pedas_Rasa_Sup_Tomat_Pedas',
#  'http://halal.addi.is.its.ac.id/ingredients/Beef',
#  'http://halal.addi.is.its.ac.id/manufactures/Suave',
#  'http://halal.addi.is.its.ac.id/ingredients/Milk_Cream',
#  'http://halal.addi.is.its.ac.id/foodproducts/Pringles_Potato_Crips_Original',
#  'http://halal.addi.is.its.ac.id/manufactures/Nature_S_Promise',
#  'http://halal.addi.is.its.ac.id/manufactures/Suavitel',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Garudafood',
#  'http://halal.addi.is.its.ac.id/ingredients/Monosodium_Glutamate',
#  'http://halal.addi.is.its.ac.id/manufactures/Carlini',
#  'http://halal.addi.is.its.ac.id/foodproducts/Zona_Ekado_Prawn_Crisps_Ekado_Udang_Kering',
#  'http://halal.addi.is.its.ac.id/foodproducts/Thai_Rice_Stir_Fry_Noodles',
#  'http://halal.addi.is.its.ac.id/manufactures/Shine_Boost',
#  'http://halal.addi.is.its.ac.id/ingredients/Coconut',
#  'http://halal.addi.is.its.ac.id/foodproducts/Abc_Minuman_Sari_Kacang_Hijau',
#  'http://halal.addi.is.its.ac.id/manufactures/Family_Choice',
#  'http://halal.addi.is.its.ac.id/foodproducts/Oreo_Biskuit_Sandwich_Coklat_Dengan_Krim_Rasa_Vanila',
#  'http://halal.addi.is.its.ac.id/manufactures/Midfield_Meat_International_Pty_Ltd',
#  'http://halal.addi.is.its.ac.id/ingredients/Semolina_Durum_Wheat',
#  'http://halal.addi.is.its.ac.id/foodproducts/Original_Love_Juice_Sirsak',
#  'http://halal.addi.is.its.ac.id/foodproducts/Good_Day_White_Cappuccino',
#  'http://halal.addi.is.its.ac.id/manufactures/Selsum_Blue',
#  'http://halal.addi.is.its.ac.id/manufactures/Welch',
#  'http://halal.addi.is.its.ac.id/foodproducts/Egg_Noodles',
#  'http://halal.addi.is.its.ac.id/ingredients/Egg_Powder',
#  'http://halal.addi.is.its.ac.id/ingredients/Buckwheat_Flour',
#  'http://halal.addi.is.its.ac.id/ingredients/Vanilla_Flavor',
#  'http://halal.addi.is.its.ac.id/foodproducts/Chicken_Noodle_Soup',
#  'http://halal.addi.is.its.ac.id/foodproducts/Noodle_Bowl_Spicy_Kung_Pao',
#  'http://halal.addi.is.its.ac.id/manufactures/Goldfish',
#  'http://halal.addi.is.its.ac.id/foodproducts/Nissin_Wafers_Coklat',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Simba_Indosnack_Makmur',
#  'http://halal.addi.is.its.ac.id/manufactures/Revolon',
#  'http://halal.addi.is.its.ac.id/foodproducts/Roma_Malkist',
#  'http://halal.addi.is.its.ac.id/manufactures/Syuhada_Kasih_Abadi',
#  'http://halal.addi.is.its.ac.id/manufactures/Wild_Friends',
#  'http://halal.addi.is.its.ac.id/ingredients/Non_Dairy_Creamer',
#  'http://halal.addi.is.its.ac.id/ingredients/Pandan_Leaves',
#  'http://halal.addi.is.its.ac.id/manufactures/Motrin',
#  'http://halal.addi.is.its.ac.id/manufactures/Tuscan',
#  'http://halal.addi.is.its.ac.id/ingredients/Acidity_Regulator',
#  'http://halal.addi.is.its.ac.id/ingredients/Cashew_Nut',
#  'http://halal.addi.is.its.ac.id/manufactures/Seeds_Of_Change',
#  'http://halal.addi.is.its.ac.id/foodproducts/Kokita_Tauco',
#  'http://halal.addi.is.its.ac.id/manufactures/Pt_Zoneindo_Global',
#  'http://halal.addi.is.its.ac.id/manufactures/Dmgm_Maxcare',
#  ...]

# %%
not_found = set(entities) - set(filtered_entities)
print(f'{not_found} could not be found in the KG! Removing them...')
entities = filtered_entities
# Out:
# {nan} could not be found in the KG! Removing them...

# %%
# menjalankan transformer untuk menghasilkan embedding
transformer = RDF2VecTransformer(walkers=[RandomWalker(2, 5)])
walk_embeddings = transformer.fit(kg, entities).transform(entities)

# %%
print(walk_embeddings)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# export ke bentuk csv
np.savetxt("rdf2vecbarusidang.csv", walk_embeddings, delimiter=",")

# %%
embedding_df2 = pd.read_csv('rdf2vecbaru.csv', delimiter = ',') 
embedding_df2
# Out:
#               1         2         3         4         5         6         7  \
# 0     -0.009982 -0.010785  0.001290 -0.002210  0.012950 -0.014055 -0.009258
# 1      0.001167 -0.009434  0.000645 -0.001031  0.008766 -0.000232 -0.008129
# 2     -0.002369 -0.013097  0.002923 -0.011869  0.007506 -0.008881 -0.008147
# 3     -0.001649 -0.005344 -0.003339 -0.005358 -0.001656  0.002563 -0.005313
# 4      0.002971 -0.004289 -0.001187 -0.002908  0.000447 -0.001315 -0.005677
# ...         ...       ...       ...       ...       ...       ...       ...
# 21232 -0.015791 -0.016935  0.000231 -0.002209  0.015589 -0.019267 -0.013298
# 21233  0.004632 -0.003782  0.004087 -0.002548  0.013088 -0.005177 -0.008472
# 21234  0.004317 -0.004459  0.001513 -0.001362  0.008050 -0.010236 -0.001776
# 21235 -0.003378 -0.014259  0.000830 -0.001121  0.007841 -0.007457 -0.013431
# 21236  0.000205 -0.003251 -0.002245 -0.006142  0.001564  0.004454  0.001447
#
#               8         9        10  ...        91        92        93  \
# 0      0.002966 -0.011494 -0.014278  ...  0.002688  0.001218  0.002677
# 1      0.005552 -0.006562 -0.005205  ...  0.003313  0.004367  0.006992
# 2      0.002153 -0.007135 -0.005334  ...  0.009371  0.006710  0.008013
# 3     -0.002229  0.001380 -0.000410  ... -0.000795 -0.000445  0.003015
# 4     -0.002215 -0.003805  0.002946  ...  0.005115  0.004029 -0.003079
# ...         ...       ...       ...  ...       ...       ...       ...
# 21232  0.003206 -0.012608 -0.007896  ...  0.008705  0.009454  0.003483
# 21233 -0.003216 -0.009668  0.003497  ...  0.012949  0.012496 -0.000363
# 21234 -0.002006 -0.006190  0.000638  ...  0.009008  0.004254 -0.003833
# 21235  0.004210 -0.013931 -0.000238  ...  0.008928 -0.000022 -0.002112
# 21236 -0.001798 -0.004124  0.002736  ...  0.001156  0.000960 -0.000880
#
#              94        95        96        97        98        99       100
# 0     -0.004382  0.008542  0.016461 -0.004507 -0.009144 -0.017365 -0.003578
# 1     -0.005176 -0.003665  0.001302 -0.007643 -0.004331 -0.007680  0.000269
# 2     -0.005424  0.010427  0.012458 -0.009169 -0.003693 -0.007440 -0.002895
# 3      0.000822 -0.003762  0.007071 -0.006090  0.000607  0.000325  0.000925
# 4     -0.003695 -0.002872  0.003256 -0.002444 -0.001074 -0.000400 -0.003808
# ...         ...       ...       ...       ...       ...       ...       ...
# 21232 -0.006225  0.009099  0.015249 -0.013845 -0.000098 -0.022265  0.001284
# 21233 -0.004499  0.002768  0.005954 -0.015915 -0.008941 -0.008630 -0.004899
# 21234 -0.006258 -0.000842  0.011535 -0.012161 -0.005507 -0.001593 -0.000905
# 21235 -0.002604  0.004747  0.009997 -0.007762 -0.016962 -0.007368 -0.003753
# 21236  0.003503  0.000389 -0.001760 -0.004960 -0.001234 -0.002596  0.002158
#
# [21237 rows x 100 columns]

# %%
df = pd.DataFrame(entities)
df = df.rename(columns={0 : 'uri'})
df
# Out:
#                                                      uri
# 0      http://halal.addi.is.its.ac.id/manufactures/Je...
# 1      http://halal.addi.is.its.ac.id/manufactures/Am...
# 2      http://halal.addi.is.its.ac.id/manufactures/St...
# 3      http://halal.addi.is.its.ac.id/manufactures/Li...
# 4      http://halal.addi.is.its.ac.id/manufactures/Yi...
# ...                                                  ...
# 21232  http://halal.addi.is.its.ac.id/manufactures/Pf...
# 21233  http://halal.addi.is.its.ac.id/manufactures/Te...
# 21234  http://halal.addi.is.its.ac.id/manufactures/By...
# 21235  http://halal.addi.is.its.ac.id/manufactures/My...
# 21236  http://halal.addi.is.its.ac.id/manufactures/Mr...
#
# [21237 rows x 1 columns]

# %%
embedding_df2.to_csv('embed rapih.csv', index='true')
df.to_csv('uri rapih.csv', index='true')

# %%
gabung1 = pd.read_csv('embed rapih.csv') 
gabung1 = gabung1.rename(columns={'Unnamed: 0': 'index'})
gabung1
# Out:
#        index         1         2         3         4         5         6  \
# 0          0 -0.009982 -0.010785  0.001290 -0.002210  0.012950 -0.014055
# 1          1  0.001167 -0.009434  0.000645 -0.001031  0.008766 -0.000232
# 2          2 -0.002369 -0.013097  0.002923 -0.011869  0.007506 -0.008881
# 3          3 -0.001649 -0.005344 -0.003339 -0.005358 -0.001656  0.002563
# 4          4  0.002971 -0.004289 -0.001187 -0.002908  0.000447 -0.001315
# ...      ...       ...       ...       ...       ...       ...       ...
# 21232  21232 -0.015791 -0.016935  0.000231 -0.002209  0.015589 -0.019267
# 21233  21233  0.004632 -0.003782  0.004087 -0.002548  0.013088 -0.005177
# 21234  21234  0.004317 -0.004459  0.001513 -0.001362  0.008050 -0.010236
# 21235  21235 -0.003378 -0.014259  0.000830 -0.001121  0.007841 -0.007457
# 21236  21236  0.000205 -0.003251 -0.002245 -0.006142  0.001564  0.004454
#
#               7         8         9  ...        91        92        93  \
# 0     -0.009258  0.002966 -0.011494  ...  0.002688  0.001218  0.002677
# 1     -0.008129  0.005552 -0.006562  ...  0.003313  0.004367  0.006992
# 2     -0.008147  0.002153 -0.007135  ...  0.009371  0.006710  0.008013
# 3     -0.005313 -0.002229  0.001380  ... -0.000795 -0.000445  0.003015
# 4     -0.005677 -0.002215 -0.003805  ...  0.005115  0.004029 -0.003079
# ...         ...       ...       ...  ...       ...       ...       ...
# 21232 -0.013298  0.003206 -0.012608  ...  0.008705  0.009454  0.003483
# 21233 -0.008472 -0.003216 -0.009668  ...  0.012949  0.012496 -0.000363
# 21234 -0.001776 -0.002006 -0.006190  ...  0.009008  0.004254 -0.003833
# 21235 -0.013431  0.004210 -0.013931  ...  0.008928 -0.000022 -0.002112
# 21236  0.001447 -0.001798 -0.004124  ...  0.001156  0.000960 -0.000880
#
#              94        95        96        97        98        99       100
# 0     -0.004382  0.008542  0.016461 -0.004507 -0.009144 -0.017365 -0.003578
# 1     -0.005176 -0.003665  0.001302 -0.007643 -0.004331 -0.007680  0.000269
# 2     -0.005424  0.010427  0.012458 -0.009169 -0.003693 -0.007440 -0.002895
# 3      0.000822 -0.003762  0.007071 -0.006090  0.000607  0.000325  0.000925
# 4     -0.003695 -0.002872  0.003256 -0.002444 -0.001074 -0.000400 -0.003808
# ...         ...       ...       ...       ...       ...       ...       ...
# 21232 -0.006225  0.009099  0.015249 -0.013845 -0.000098 -0.022265  0.001284
# 21233 -0.004499  0.002768  0.005954 -0.015915 -0.008941 -0.008630 -0.004899
# 21234 -0.006258 -0.000842  0.011535 -0.012161 -0.005507 -0.001593 -0.000905
# 21235 -0.002604  0.004747  0.009997 -0.007762 -0.016962 -0.007368 -0.003753
# 21236  0.003503  0.000389 -0.001760 -0.004960 -0.001234 -0.002596  0.002158
#
# [21237 rows x 101 columns]

# %%
gabung2 = pd.read_csv('uri rapih.csv') 
gabung2 = gabung2.rename(columns={'Unnamed: 0': 'index'})
gabung2
# Out:
#        index                                                uri
# 0          0  http://halal.addi.is.its.ac.id/manufactures/Je...
# 1          1  http://halal.addi.is.its.ac.id/manufactures/Am...
# 2          2  http://halal.addi.is.its.ac.id/manufactures/St...
# 3          3  http://halal.addi.is.its.ac.id/manufactures/Li...
# 4          4  http://halal.addi.is.its.ac.id/manufactures/Yi...
# ...      ...                                                ...
# 21232  21232  http://halal.addi.is.its.ac.id/manufactures/Pf...
# 21233  21233  http://halal.addi.is.its.ac.id/manufactures/Te...
# 21234  21234  http://halal.addi.is.its.ac.id/manufactures/By...
# 21235  21235  http://halal.addi.is.its.ac.id/manufactures/My...
# 21236  21236  http://halal.addi.is.its.ac.id/manufactures/Mr...
#
# [21237 rows x 2 columns]

# %%
gabungan = gabung2.merge(gabung1, on = 'index')
gabungan = gabungan.drop(columns='index')
gabungan
# Out:
#                                                      uri         1         2  \
# 0      http://halal.addi.is.its.ac.id/manufactures/Je... -0.009982 -0.010785
# 1      http://halal.addi.is.its.ac.id/manufactures/Am...  0.001167 -0.009434
# 2      http://halal.addi.is.its.ac.id/manufactures/St... -0.002369 -0.013097
# 3      http://halal.addi.is.its.ac.id/manufactures/Li... -0.001649 -0.005344
# 4      http://halal.addi.is.its.ac.id/manufactures/Yi...  0.002971 -0.004289
# ...                                                  ...       ...       ...
# 21232  http://halal.addi.is.its.ac.id/manufactures/Pf... -0.015791 -0.016935
# 21233  http://halal.addi.is.its.ac.id/manufactures/Te...  0.004632 -0.003782
# 21234  http://halal.addi.is.its.ac.id/manufactures/By...  0.004317 -0.004459
# 21235  http://halal.addi.is.its.ac.id/manufactures/My... -0.003378 -0.014259
# 21236  http://halal.addi.is.its.ac.id/manufactures/Mr...  0.000205 -0.003251
#
#               3         4         5         6         7         8         9  \
# 0      0.001290 -0.002210  0.012950 -0.014055 -0.009258  0.002966 -0.011494
# 1      0.000645 -0.001031  0.008766 -0.000232 -0.008129  0.005552 -0.006562
# 2      0.002923 -0.011869  0.007506 -0.008881 -0.008147  0.002153 -0.007135
# 3     -0.003339 -0.005358 -0.001656  0.002563 -0.005313 -0.002229  0.001380
# 4     -0.001187 -0.002908  0.000447 -0.001315 -0.005677 -0.002215 -0.003805
# ...         ...       ...       ...       ...       ...       ...       ...
# 21232  0.000231 -0.002209  0.015589 -0.019267 -0.013298  0.003206 -0.012608
# 21233  0.004087 -0.002548  0.013088 -0.005177 -0.008472 -0.003216 -0.009668
# 21234  0.001513 -0.001362  0.008050 -0.010236 -0.001776 -0.002006 -0.006190
# 21235  0.000830 -0.001121  0.007841 -0.007457 -0.013431  0.004210 -0.013931
# 21236 -0.002245 -0.006142  0.001564  0.004454  0.001447 -0.001798 -0.004124
#
#        ...        91        92        93        94        95        96  \
# 0      ...  0.002688  0.001218  0.002677 -0.004382  0.008542  0.016461
# 1      ...  0.003313  0.004367  0.006992 -0.005176 -0.003665  0.001302
# 2      ...  0.009371  0.006710  0.008013 -0.005424  0.010427  0.012458
# 3      ... -0.000795 -0.000445  0.003015  0.000822 -0.003762  0.007071
# 4      ...  0.005115  0.004029 -0.003079 -0.003695 -0.002872  0.003256
# ...    ...       ...       ...       ...       ...       ...       ...
# 21232  ...  0.008705  0.009454  0.003483 -0.006225  0.009099  0.015249
# 21233  ...  0.012949  0.012496 -0.000363 -0.004499  0.002768  0.005954
# 21234  ...  0.009008  0.004254 -0.003833 -0.006258 -0.000842  0.011535
# 21235  ...  0.008928 -0.000022 -0.002112 -0.002604  0.004747  0.009997
# 21236  ...  0.001156  0.000960 -0.000880  0.003503  0.000389 -0.001760
#
#              97        98        99       100
# 0     -0.004507 -0.009144 -0.017365 -0.003578
# 1     -0.007643 -0.004331 -0.007680  0.000269
# 2     -0.009169 -0.003693 -0.007440 -0.002895
# 3     -0.006090  0.000607  0.000325  0.000925
# 4     -0.002444 -0.001074 -0.000400 -0.003808
# ...         ...       ...       ...       ...
# 21232 -0.013845 -0.000098 -0.022265  0.001284
# 21233 -0.015915 -0.008941 -0.008630 -0.004899
# 21234 -0.012161 -0.005507 -0.001593 -0.000905
# 21235 -0.007762 -0.016962 -0.007368 -0.003753
# 21236 -0.004960 -0.001234 -0.002596  0.002158
#
# [21237 rows x 101 columns]

# %%
gabungan.to_csv('RDF2Vec ready.csv')
